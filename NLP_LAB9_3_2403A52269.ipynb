# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52269-code/NLP/blob/main/NLP_LAB9_3_2403A52269.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install Gensim**

# %%
# !pip install gensim
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 37.9 MB/s eta 0:00:00
# ...

# %%
import gensim
from gensim.models import KeyedVectors

import numpy as np

from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

# %% [markdown]
# # **Load Pretrained Word2Vec Model**

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors
model = api.load("word2vec-google-news-300")
print("Vocabulary Size:", len(model.key_to_index))

word = "king"
vector = model[word]

print("\nWord:", word)
print("Vector length:", len(vector))
print("First 10 values of the vector:\n", vector[:10])
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Vocabulary Size: 3000000
#
# Word: king
# Vector length: 300
# First 10 values of the vector:
#  [ 0.12597656  0.02978516  0.00860596  0.13964844 -0.02563477 -0.03613281
#   0.11181641 -0.19824219  0.05126953  0.36328125]

# %% [markdown]
# # **Load Pretrained GloVe Model**

# %%
import gensim.downloader as api
model = api.load("glove-wiki-gigaword-100")

print("Vocabulary Size:", len(model.key_to_index))

word = "king"
vector = model[word]

print("\nWord:", word)
print("Vector length:", len(vector))
print("First 10 values of the vector:\n", vector[:10])
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# Vocabulary Size: 400000
#
# Word: king
# Vector length: 100
# First 10 values of the vector:
#  [-0.32307 -0.87616  0.21977  0.25268  0.22976  0.7388  -0.37954 -0.35307
#  -0.84369 -1.1113 ]

# %%
import gensim.downloader as api
model = api.load("glove-wiki-gigaword-100")

word_pairs = [
    ("doctor", "nurse"),
    ("cat", "dog"),
    ("car", "bus"),
    ("king", "queen"),
    ("man", "woman"),
    ("teacher", "student"),
    ("apple", "banana"),
    ("computer", "keyboard"),
    ("sun", "moon"),
    ("river", "water")
]

print("Word Similarity Scores:\n")

for w1, w2 in word_pairs:
    similarity = model.similarity(w1, w2)
    print(f"{w1} - {w2} : {similarity:.4f}")
# Out:
# Word Similarity Scores:
#
# doctor - nurse : 0.7522
# cat - dog : 0.8798
# car - bus : 0.7373
# king - queen : 0.7508
# man - woman : 0.8323
# teacher - student : 0.8083
# apple - banana : 0.5054
# computer - keyboard : 0.5418
# sun - moon : 0.6138
# river - water : 0.6306

# %% [markdown]
# # GloVe Similarity

# %%
import gensim.downloader as api
model = api.load("glove-wiki-gigaword-100")

chosen_words = ["king", "university", "doctor", "car", "music"]

for word in chosen_words:
    print(f"\nTop similar words for '{word}':\n")

    similar_words = model.most_similar(word, topn=5)

    for similar_word, score in similar_words:
        print(f"{similar_word} : {score:.4f}")
# Out:
# Top similar words for 'king':
#
# prince : 0.7682
# queen : 0.7508
# son : 0.7021
# brother : 0.6986
# monarch : 0.6978
#
# Top similar words for 'university':
#
# college : 0.8294
# harvard : 0.8156
# yale : 0.8114
# professor : 0.8104
# graduate : 0.7993
#
# Top similar words for 'doctor':
#
# physician : 0.7673
# nurse : 0.7522
# dr. : 0.7175
# doctors : 0.7081
# patient : 0.7074
#
# Top similar words for 'car':
#
# vehicle : 0.8631
# truck : 0.8598
# cars : 0.8372
# driver : 0.8186
# driving : 0.7813
#
# Top similar words for 'music':
#
# musical : 0.8128
# songs : 0.7978
# dance : 0.7897
# pop : 0.7863
# recording : 0.7651

# %% [markdown]
# # Word Similarity

# %%
import gensim.downloader as api

model = api.load("word2vec-google-news-300")

result1 = model.most_similar(
    positive=["king", "woman"],
    negative=["man"],
    topn=5
)

result2 = model.most_similar(
    positive=["paris", "india"],
    negative=["france"],
    topn=5
)

result3 = model.most_similar(
    positive=["teacher", "hospital"],
    negative=["school"],
    topn=5
)

print("\nking - man + woman = ?")
print(result1)

print("\nparis - france + india = ?")
print(result2)

print("\nteacher - school + hospital = ?")
print(result3)
# Out:
# king - man + woman = ?
# [('queen', 0.7118193507194519), ('monarch', 0.6189674139022827), ('princess', 0.5902431011199951), ('crown_prince', 0.5499460697174072), ('prince', 0.5377321839332581)]
#
# paris - france + india = ?
# [('chennai', 0.5442505478858948), ('delhi', 0.5149926543235779), ('mumbai', 0.5024341344833374), ('hyderabad', 0.49932485818862915), ('gujarat', 0.48732805252075195)]
#
# teacher - school + hospital = ?
# [('Hospital', 0.6331106424331665), ('nurse', 0.6280134320259094), ('hopsital', 0.6217317581176758), ('intensive_care', 0.5683753490447998), ('Hosptial', 0.5647749304771423)]

# %% [markdown]
# # **Word Similarity**

# %%
similarity_w2v = model.similarity("king", "queen")
print("Word2Vec Similarity (king, queen):", similarity_w2v)
# Out:
# Word2Vec Similarity (king, queen): 0.6510957

# %% [markdown]
# # **GloVe Similarity**

# %%
similarity_glove = model.similarity("king", "queen")
print("GloVe Similarity (king, queen):", similarity_glove)
# Out:
# GloVe Similarity (king, queen): 0.6510957
