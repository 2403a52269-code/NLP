# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52269-code/NLP/blob/main/NLP_1_2_(2403A52269).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy

# %%
import nltk
import spacy

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = """ Hi I am a 2nd year btech student studying in SR University, I am a passinate AIML student intrested in Software development."""

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
word_count = len(words)

print("Number of words:", word_count)
# Out:
# Number of words: 24

# %%
print(text)
# Out:
#  Hi I am a 2nd year btech student studying in SR University, I am a passinate AIML student intrested in Software development.

# %%
lower_text = text.lower()
print("Lowercase text:\n")
print(lower_text)
# Out:
# Lowercase text:
#
#  hi i am a 2nd year btech student studying in sr university, i am a passinate aiml student intrested in software development.
